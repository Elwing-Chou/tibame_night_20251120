# %% [markdown]
# <a href="https://colab.research.google.com/github/Elwing-Chou/tibame_night_20251120/blob/main/tibame20251220.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import urllib.request as req

url = "https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=36632&geo=TW%2CHK"
f = req.urlopen(url)
content = f.read()
content = json.loads(content)

danmus = content["data"]["danmu"]
# Out:
# [{'text': '二刷',
#   'color': '#FFFFFF',
#   'size': 1,
#   'position': 0,
#   'time': 0,
#   'sn': 42903755,
#   'userid': 'qaz1210731'},
#  {'text': '吉伊卡哇！',
#   'color': '#FFFFFF',
#   'size': 1,
#   'position': 0,
#   'time': 0,
#   'sn': 45641971,
#   'userid': 'dodylee0107'},
#  {'text': '感謝動畫瘋！',
#   'color': '#FFFFFF',
#   'size': 1,
#   'position': 0,
#   'time': 0,
#   'sn': 45796240,
#   'userid': 'hyg125'},
#  {'text': '2025.11.24簽',
#   'color': '#FDE53D',
#   'size': 1,
#   'position': 0,
#   'time': 0,
#   'sn': 47316552,
#   'userid': 'MilkTea157'},
#  {'text': '吉依好可愛',
#   'color': '#FFFFFF',
#   'size': 1,
#   'position': 0,
#   'time': 5,
#   'sn': 40580321,
#   'userid': 'KingOrange69'},
#  {'text': '哈嘍',
#   'color': '#FFFFFF',
#   'size': 1,
#   'position': 0,
#   'time': 5,
#   'sn': 40657118,
#   'userid': 'rwan123'},
#  {'text': '簽',
#   'color': '#FFFFFF',
#   'size': 1,
#   'position': 0,
#   'time': 5,
#   'sn': 41446388,
#   'userid': 'nehsh101'},
# ...
