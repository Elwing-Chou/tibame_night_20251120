# %% [markdown]
# <a href="https://colab.research.google.com/github/Elwing-Chou/tibame_night_20251120/blob/main/tibame_night_20251204.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# WIN: -headers "Origin: https://ani.gamer.com.tw" -i "" anime.mp4
#
# MAC: -headers 'Origin: https://ani.gamer.com.tw' -i '' anime.mp4
#
# cd xxx
# 可執行的程式 參數
# 1. 位置參數(放最後面, 一定會帶入的)
# 2. 告訴她參數拿來幹嗎
#    a. 短參數: -V               -短參數名 值
#    b. 長參數: --version        --長參數名 值
# ```

# %%
# 專屬功能
f = open("a.txt", "w", encoding="utf-8")
# write(f, "abcde")
f.write("abcde")
# close(f)
f.close()

# %%
f = open("a.txt", "r", encoding="utf-8")
# content = read(f)
content = f.read()
f.close()
print(content)
# Out:
# abcde

# %% [markdown]
# ```
# 群集型態
# 1. 清單(list): []
#    key: 0 1 2 3
#    放同類型的很多東西
# 2. 字典(dict): {自訂key:val}
#    聚集很多東西表示一個複雜的單位的
#
# list+dict: 無敵(JSON格式)
#
# 展覽清單 = [
#     {
#         展覽名:xxx展,
#         展覽地點:[
#             {聯絡人:xxx, 名稱:xxx, 電話:xxx}
#         ]
#     }
#
# ]
#
# ```

# %%
import json
import urllib.request as req

url = "https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=36632&geo=TW%2CHK"
f = req.urlopen(url)
content = f.read()
print(type(content))
content = json.loads(content)
print(type(content))
# Out:
# <class 'bytes'>
# <class 'dict'>
# {'data': {'danmu': [{'text': '二刷', 'color': '#FFFFFF', 'size': 1, 'position': 0, 'time': 0, 'sn': 42903755, 'userid': 'qaz1210731'}, {'text': '吉伊卡哇！', 'color': '#FFFFFF', 'size': 1, 'position': 0, 'time': 0, 'sn': 45641971, 'userid': 'dodylee0107'}, {'text': '感謝動畫瘋！', 'color': '#FFFFFF', 'size': 1, 'position': 0, 'time': 0, 'sn': 45796240, 'userid': 'hyg125'}, {'text': '2025.11.24簽', 'color': '#FDE53D', 'size': 1, 'position': 0, 'time': 0, 'sn': 47316552, 'userid': 'MilkTea157'}, {'text': '吉依好可愛', 'color': '#FFFFFF', 'size': 1, 'position': 0, 'time': 5, 'sn': 40580321, 'userid': 'KingOrange69'}, {'text': '哈嘍', 'color': '#FFFFFF', 'size': 1, 'position': 0, 'time': 5, 'sn': 40657118, 'userid': 'rwan123'}, {'text': '簽', 'color': '#FFFFFF', 'size': 1, 'position': 0, 'time': 5, 'sn': 41446388, 'userid': 'nehsh101'}, {'text': '1', 'color': '#FFFFFF', 'size': 1, 'position': 0, 'time': 5, 'sn': 42235007, 'userid': 'zxc520031'}, {'text': '個', 'color': '#FFFFFF', 'size': 1, 'position': 0, 'time': 5, 'sn': 42576215, 'userid': 'd3498115'}, {'text': '千', 'color': '#FFFFFF', 'size': 1, 'position': 0, 'time': 6, 'sn': 43809180, 'userid': 'pikachiuweii'}, {'text': '靠真的好可愛', 'color': '#FFFFFF', 'size': 1, 'position': 0, 'time': 10, 'sn': 38700844, 'userid': 'milkppt'}, {'text': '簽', 'color': '#FF0026', 'size': 1, 'position': 0, 'time': 15, 'sn': 42812053, 'userid': 'Ceadda127'}, {'text': '好可愛啊😍', 'color': '#FFFFFF', 'size': 2, 'position': 0, 'time': 15, 'sn': 43532304, 'userid': 'bellaliu1230'}, {'text': '兄弟們 我來了！', 'color': '#FFFFFF', 'size': 1, 'position': 0, 'time': 16, 'sn': 42125192, 'userid': 'good78221125'}, {'text': '簽', 'color': '#FFFFFF', 'size': 1, 'position': 0, 'time': 19, 'sn': 42456696, 'userid': 'Rei9488'}, {'text': '總點閱數千萬了，什麼時候出中文續集QAQ', 'color': '#FFFFFF', 'size': 1, 'position': 0, 'time': 23, 'sn': 41862583, 'userid': 'IONCHIPS'}, {'text': '我怎麼可能會輸給吉伊卡哇', 'color': '#A7FE39', 'size': 1, 'position': 1, 'time': 23, 'sn': 42523886, 'userid': 'sunny254ww'}, {'text': '巴哈我大哥', 'color': '#FFFFFF', 'size': 1, 'position': 0, 'time': 24, 'sn': 37399442, 'userid': 'gemmalinn'}, {'text': '兄弟', 'color': '#FFFFFF', 'size': 1, 'position': 0, 'time': 25, 'sn': 37090866, 'userid': 'k246836'}, {'text': '😆', 'color': '#FFFFFF', 'size': 1, 'position': 0, 'time': 25, 'sn': 37543537, 'userid': 'a59875987'}, {'text': '兄弟', 'color': '#FFFFFF', 'size': 1, 'position': 0, 'time': 25, 'sn': 39165765, 'userid': 'coolmus64'}, {'text': '這真的超可愛', 'color': '#FFFFFF', 'size': 1, 'position': 0, 'time': 25, 'sn': 41891414, 'userid': 'bubble0315'}, {'text': '好可愛', 'color': '#FFFFFF', 'size': 1, 'position': 0, 'time': 25, 'sn': 43842076, 'userid': 'jerry990126'}, {'text': '好棒喔  謝謝巴哈', 'color': '#FFFFFF', 'size': 1, 'position': 0, 'time': 28, 'sn': 37092222, 'userid': 'kifar13'}, {'text': '這部很治癒 也有一些恐怖的細節', 'color': '#FF9496', 'size': 2, 'position': 0, 'time': 30, 'sn': 42780785, 'userid': 'kkjt1030'}, {'text': '可愛', 'color': '#FFFFFF', 'size': 1, 'position': 0, 'time': 34, 'sn': 42096407, 'userid': 'smile10101'}, {'text': '感謝動畫瘋！', 'color': '#FFFFFF', 'size': 1, 'position': 0, 'time': 35, 'sn': 37089028, 'userid': 'cathykao1015'}, {'text': '1130611', 'color': '#FFFFFF', 'size': 1, 'position': 0, 'time': 35, 'sn': 39908396, 'userid': 'Cute710'}, {'text': '體感一分鐘笑爆....XD', 'color': '#FFFFFF', 'size': 1, 'position': 0, 'time': 40, 'sn': 40543483, 'userid': 'ncbob'}, {'text': '簽', 'color': '#FFFFFF', 'size': 1, 'position': 0, 'time': 44, 'sn': 42661483, 'userid': 'm617007'}, {'text': '謝謝巴哈大哥', 'color': '#FFFFFF', 'size': 1, 'position': 0, 'time': 47, 'sn': 41916318, 'userid': 'zero77716'}, {'text': '好可愛啊！我的天', 'color': '#FF9496', 'size': 1, 'position': 1, 'time': 49, 'sn': 45101628, 'userid': 'kateihan0307'}, {'text': '巴哈我大哥啊啊啊啊啊', 'color': '#FFFFFF', 'size': 1, 'position': 0, 'time': 50, 'sn': 37116180, 'userid': 'iorimo0u0'}, {'text': '兄弟…', 'color': '#FFFFFF', 'size': 1, 'position': 0, 'time': 50, 'sn': 38425610, 'userid': 'zzxcc132465'}, {'text': '日本', 'color': ' ...
