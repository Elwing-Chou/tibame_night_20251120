# %% [markdown]
# <a href="https://colab.research.google.com/github/Elwing-Chou/tibame_night_20251120/blob/main/tibame_20251125.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def is_leap_year(year):
    ans = False
    if year % 400 == 0:
        ans = True
    elif year % 100 == 0:
        ans = False
    elif year % 4 == 0:
        ans = True
    else:
        ans = False
    return ans

# %%
def is_date_valid(date_checked):
    day = date_checked % 100
    remain = date_checked // 100
    month = remain % 100
    year = remain // 100

    if year > 0:
        if 1 <= month <= 12:
            day_limit_per_month = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
            day_limit = day_limit_per_month[month-1]
            if month == 2 and is_leap_year(year) == True:
                day_limit = day_limit + 1
            if 1 <= day <= day_limit:
                # 日期合理
                return True
    # 預設不是對的
    return False

# %%
def fully_squared_1(start=4499, max_count=10):
    # start = 4499
    ans = []
    count = 0
    while True:
        date_checked = start ** 2
        if is_date_valid(date_checked) == True:
            # print(date_checked)
            ans.append(date_checked)
            count = count + 1
        if count == max_count:
            break
        start = start + 1
    return ans
# fully_squared_1()

# %% [markdown]
# ```
# 想法1: 20241001->20241002
# 想法2: 4499->4500->4501
#
# datetime: strptime strftime
#
# strptime: str->datetime型態
# strftime: datetime型態->str
#
# ```

# %%
import datetime as dt
# demo
# 2024-10-01
read_pat = "%Y-%m-%d"
d = dt.datetime.strptime("2024-10-01", read_pat)
write_pat = "%Y/%m/%d 紀念日"
d_str = d.strftime(write_pat)
print(d_str)
# Out:
# 2024/10/01 紀念日
