# %% [markdown]
# <a href="https://colab.research.google.com/github/Elwing-Chou/tibame_night_20251120/blob/main/tibame_20241120.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 3
print(a)
# Out:
# 3

# %% [markdown]
# Latex Math
#
# $ \frac{1}{3+\pi} $

# %%
print(a+2)
# Out:
# 5
